# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_csv('samples.csv')

# %%
myCols = ["id_product",	"Region",	"Country",	"Zone",	"Year",	"Quarter_cumuled",	"Quarter",	"Month_1",	"Month_2",	"Month_3",	'Month_4']

# %%
df = df[myCols]

# %%
X = df.sort_values(by='Quarter_cumuled')
X
# Out:
#     id_product  Region  Country  Zone  Year  Quarter_cumuled  Quarter  \
# 17      104657       2       28    10  2020                1        3
# 5       149445       2       24     6  2020                1        3
# 7       168061       2       17     0  2020                1        3
# 1       224631       0        4     2  2021                2        1
# 2       104047       2       28    10  2021                2        1
# 4       159924       2       24     6  2021                2        1
# 18      191320       2        1     0  2021                2        1
# 12      139181       2        8     3  2021                2        1
# 11       28171       1        0     9  2021                2        1
# 0       156160       2        8     3  2021                3        2
# 16       19781       1        0     9  2021                3        2
# 8        64939       3       29    11  2021                4        3
# ...

# %%
y = df.sort_values(by='Quarter_cumuled')['Month_2']

# %%
y
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /home/ion/git/HiParis/app/viz.ipynb Cell 7 line 1
# ----> <a href='vscode-notebook-cell://ssh-remote%2B164.68.113.115/home/ion/git/HiParis/app/viz.ipynb#X10sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> y
#
# NameError: name 'y' is not defined

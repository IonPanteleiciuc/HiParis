# %%
import pandas as pd

# %%
df = pd.read_csv('samples.csv')

# %%
df
# Out:
#     id_product  Region  Country  Zone  Reference proxy  Product  Line proxy  \
# 0       156160       2        8     3            13523                    4
# 1       224631       0        4     2            12778                    4
# 2       104047       2       28    10             3513                    3
# 3        11823       1        0     9              672                    1
# 4       159924       2       24     6             3496                    3
# 5       149445       2       24     6             7529                    4
# 6        25324       1        0     9             1882                    1
# 7       168061       2       17     0            10764                    4
# 8        64939       3       29    11             6848                    4
# 9       140385       2        8     3             6404                    4
# 10       68682       3       29    11             7533                    4
# ...

# %%
for x in df.columns:
  print(x)
# Out:
# id_product
# Region
# Country
# Zone
# Reference proxy
# Product  Line proxy
# Customer Persona proxy
# Strategic Product Family proxy
# Product Life cycel status
# Month 1
# Month 2
# Month 3
# Month 4
# Quarter
# Year
# Quarter_cumuled
# Site_country
# Site_type
# Energy_Price_Index_1
# Energy_Price_Index_2
# Energy_Price_Index_3
# Energy_Price_Index_4
# Headline_Consumer_Index_1
# Headline_Consumer_Index_2
# Headline_Consumer_Index_3
# Headline_Consumer_Index_4
# GSCPI_1
# GSCPI_2
# GSCPI_3
# GSCPI_4
# Agriculture, forestry, and fishing, value added (annual % growth)
# Exports of goods and services (annual % growth)
# Final consumption expenditure (annual % growth)
# GDP (current US$)
# Gross capital formation (annual % growth)
# Imports of goods and services (annual % growth)
# Industry (including construction), value added (annual % growth)
# Manufacturing, value added (annual % growth)
# Services, value added (annual % growth)
# unMember
# netChange
# rank
# ...

# %%
len(df.columns)
# Out:
# 46

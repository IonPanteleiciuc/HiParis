# %%
import numpy as np
import pandas as pd

# %%
path = 'datasets_hi4/'

df_train = pd.read_csv(path + 'train-data.csv', sep=';', index_col=['index'])

df_lpi = pd.read_csv(path + 'extra-dataset/LPIextend.csv', sep=',')
df_gscpi = pd.read_csv(path + 'extra-dataset/GSCPI_data.csv', sep=',')
df_wb_economic = pd.read_csv(path + 'extra-dataset/worldbank_economic_data.csv', sep=',')
df_wb_inflation = pd.read_csv(path + 'extra-dataset/worldbank_inflation_data.csv', sep=',')

# %%
df_wb_inflation.shape
# Out:
# (8127, 4)

# %%
df_train.head()
# Out:
#          id_product  Region Country            Site                Operations  \
# index
# 645874       156160  EUROPE      DE    NL_DC_Venray         Europe Operations
# 469488       224631   CHINA      CN  CN_DC_Shanghai          China Operations
# 348904       104047  EUROPE      GB       NL_DC_HLD         Europe Operations
# 1725822       11823    EAJP      AU     AU_DC_Perth  International Operations
# 404781       159924  EUROPE      ES       NL_DC_HLD         Europe Operations
#
#                    Zone         Cluster  Reference proxy Product  Line proxy  \
# index
# 645874             DACH         Germany  reference-13523      Product Line-4
# 469488       China & HK           China  reference-12778      Product Line-4
# 348904   UK and Ireland  United Kingdom   reference-3513      Product Line-3
# 1725822         Pacific       Australia    reference-672      Product Line-1
# 404781           Iberia           Spain   reference-3496      Product Line-3
#
# ...

# %%
df_train[df_train['Date'] == 'may-jul 2023']
# Out:
#          id_product  Region Country                 Site  \
# index
# 2026075       67219     NAM      US  US_DC_Mechanicsburg
# 2082484      123628  EUROPE      IT        IT_DC_Venaria
# 2086406      127550  EUROPE      IT        IT_DC_Venaria
# 2148788      189932  EUROPE      BE         NL_DC_Venray
# 2085051      126195  EUROPE      SE         SE_DC_Orebro
# ...             ...     ...     ...                  ...
# 2050022       91166     NAM      US            US_DC_LAD
# 2091556      132700  EUROPE      IT        IT_DC_Venaria
# 1981892       23036    EAJP      AU         AU_DC_Sydney
# 1982576       23720    EAJP      AU         AU_DC_Sydney
# 2188093      229237   CHINA      CN       CN_DC_Shanghai
#
#                        Operations              Zone    Cluster  \
# index
# 2026075  North America Operations                US        USA
# 2082484         Europe Operations             Italy      Italy
# 2086406         Europe Operations             Italy      Italy
# ...

# %%
df_lpi.head()
# Out:
#    Unnamed: 0  ID      Country  population (2023)      area  landAreaKm  \
# 0           0   0    Singapore          6014723.0     710.0       718.0
# 1           1   1      Finland          5545475.0  338424.0    303940.0
# 2           2   2      Denmark          5910913.0   43094.0     40000.0
# 3           3   3      Germany         83294633.0  357114.0    349390.0
# 4           4   4  Netherlands         17618299.0   41850.0     33670.0
#
#   unMember  netChange  growthRate  worldPercentage  ...  Infrastructure Score  \
# 0     True     0.0012      0.0065           0.0008  ...                   4.6
# 1     True     0.0001      0.0009           0.0007  ...                   4.2
# 2     True     0.0009      0.0049           0.0007  ...                   4.1
# 3     True    -0.0012     -0.0009           0.0104  ...                   4.3
# 4     True     0.0017      0.0031           0.0022  ...                   4.2
#
# ...

# %%
df_wb_economic.head()
# Out:
#                        Country  Year  \
# 0                  Afghanistan  2020
# 1                  Afghanistan  2021
# 2                  Afghanistan  2022
# 3                  Afghanistan  2023
# 4  Africa Eastern and Southern  2020
#
#    Agriculture, forestry, and fishing, value added (annual % growth)  \
# 0                                               5.94
# 1                                              -2.83
# 2                                                NaN
# 3                                                NaN
# 4                                               3.15
#
#    Exports of goods and services (annual % growth)  \
# 0                                              NaN
# 1                                              NaN
# 2                                              NaN
# 3                                              NaN
# 4                                           -11.41
#
#    Final consumption expenditure (annual % growth)  GDP (current US$)  \
# ...

# %%
df_gscpi.head()
# Out:
#   Year-Month     GSCPI
# 0    2020-01  0.090108
# 1    2020-02  1.191976
# 2    2020-03  2.546002
# 3    2020-04  3.161703
# 4    2020-05  2.537110

# %%
df_wb_inflation.head()
# Out:
#        Country Year-Month  Energy Price Index  Headline Consumer Price Index
# 0  Afghanistan    2020-01                 NaN                     154.191402
# 1  Afghanistan    2020-02                 NaN                     153.366469
# 2  Afghanistan    2020-03                 NaN                     153.676014
# 3  Afghanistan    2020-04                 NaN                            NaN
# 4  Afghanistan    2020-05                 NaN                            NaN
